# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=69aeb7a9570dd8475aae677a4aa3cbe6

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 775

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        current_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": current_description,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 1 | baruun-urt
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | tura
# Processing Record 6 of Set 1 | tubruq
# City not found. Skipping...
# Processing Record 7 of Set 1 | fort saint james
# Processing Record 8 of Set 1 | hermanus
# Processing Record 9 of Set 1 | mataura
# Processing Record 10 of Set 1 | toliary
# City not found. Skipping...
# Processing Record 11 of Set 1 | saldanha
# Processing Record 12 of Set 1 | wanaka
# Processing Record 13 of Set 1 | esperance
# Processing Record 14 of Set 1 | ahuimanu
# Processing Record 15 of Set 1 | busselton
# Processing Record 16 of Set 1 | castro
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | moose factory
# Processing Record 19 of Set 1 | butaritari
# Processing Record 20 of Set 1 | marovoay
# Processing Record 21 of Set 1 | tambul
# City not found. Skipping...
# Processing Record 22 of Set 1 | tabuk
# Processing Record 23 of Set 1 | saint george
# Processing Record 24 of Set 1 | impfondo
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 27 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | makakilo city
# Processing Record 30 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 1 | rolim de moura
# City not found. Skipping...
# Processing Record 32 of Set 1 | barrow
# Processing Record 33 of Set 1 | san juan
# Processing Record 34 of Set 1 | barcelos
# Processing Record 35 of Set 1 | tuktoyaktuk
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | vaini
# Processing Record 38 of Set 1 | hobart
# Processing Record 39 of Set 1 | sitka
# Processing Record 40 of Set 1 | kazachinskoye
# Processing Record 41 of Set 1 | mar del plata
# Processing Record 42 of Set 1 | albany
# Processing Record 43 of Set 1 | san patricio
# Processing Record 44 of Set 1 | kruisfontein
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | rikitea
# Processing Record 47 of Set 1 | salamiyah
# Processing Record 48 of Set 1 | shaunavon
# Processing Record 49 of Set 1 | nukus
# Processing Record 50 of Set 1 | airai
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 2 | avarua
# Processing Record 4 of Set 2 | new norfolk
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | ndele
# Processing Record 7 of Set 2 | hambantota
# Processing Record 8 of Set 2 | santa rosalia
# Processing Record 9 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 10 of Set 2 | gunjur
# Processing Record 11 of Set 2 | talawdi
# City not found. Skipping...
# Processing Record 12 of Set 2 | hovd
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | bam
# Processing Record 15 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 2 | khatanga
# Processing Record 17 of Set 2 | liverpool
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | havelock
# Processing Record 20 of Set 2 | ribeira grande
# Processing Record 21 of Set 2 | laguna
# Processing Record 22 of Set 2 | luau
# Processing Record 23 of Set 2 | san pedro
# Processing Record 24 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 2 | tazovskiy
# Processing Record 26 of Set 2 | hermiston
# Processing Record 27 of Set 2 | bonavista
# Processing Record 28 of Set 2 | iqaluit
# Processing Record 29 of Set 2 | longyearbyen
# Processing Record 30 of Set 2 | cape town
# Processing Record 31 of Set 2 | machinga
# Processing Record 32 of Set 2 | mmabatho
# Processing Record 33 of Set 2 | idanre
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | arlit
# Processing Record 36 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 37 of Set 2 | miranorte
# City not found. Skipping...
# Processing Record 38 of Set 2 | kalmunai
# Processing Record 39 of Set 2 | the pas
# Processing Record 40 of Set 2 | okato
# Processing Record 41 of Set 2 | stamsund
# City not found. Skipping...
# Processing Record 42 of Set 2 | saint anthony
# Processing Record 43 of Set 2 | roald
# Processing Record 44 of Set 2 | paita
# Processing Record 45 of Set 2 | chokurdakh
# Processing Record 46 of Set 2 | huanren
# Processing Record 47 of Set 2 | sayyan
# Processing Record 48 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 49 of Set 2 | zyryanovsk
# Processing Record 50 of Set 2 | norman wells
# Processing Record 1 of Set 3 | bethel
# Processing Record 2 of Set 3 | vardo
# Processing Record 3 of Set 3 | saskylakh
# Processing Record 4 of Set 3 | srednekolymsk
# Processing Record 5 of Set 3 | carnarvon
# Processing Record 6 of Set 3 | souillac
# Processing Record 7 of Set 3 | mexticacan
# Processing Record 8 of Set 3 | jinzhou
# Processing Record 9 of Set 3 | balkanabat
# Processing Record 10 of Set 3 | tricase
# Processing Record 11 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 12 of Set 3 | shingu
# Processing Record 13 of Set 3 | hithadhoo
# Processing Record 14 of Set 3 | las vegas
# Processing Record 15 of Set 3 | victoria
# Processing Record 16 of Set 3 | katherine
# Processing Record 17 of Set 3 | saint-augustin
# Processing Record 18 of Set 3 | carutapera
# Processing Record 19 of Set 3 | ola
# Processing Record 20 of Set 3 | labuhan
# Processing Record 21 of Set 3 | guangyuan
# Processing Record 22 of Set 3 | fortuna
# Processing Record 23 of Set 3 | nemuro
# Processing Record 24 of Set 3 | armidale
# Processing Record 25 of Set 3 | severodvinsk
# Processing Record 26 of Set 3 | mayumba
# Processing Record 27 of Set 3 | narsaq
# Processing Record 28 of Set 3 | ostrovnoy
# Processing Record 29 of Set 3 | saint-philippe
# Processing Record 30 of Set 3 | mogadishu
# Processing Record 31 of Set 3 | sambava
# Processing Record 32 of Set 3 | hamilton
# Processing Record 33 of Set 3 | luderitz
# Processing Record 34 of Set 3 | torrevieja
# Processing Record 35 of Set 3 | atuona
# Processing Record 36 of Set 3 | hilo
# Processing Record 37 of Set 3 | kushima
# Processing Record 38 of Set 3 | emerald
# Processing Record 39 of Set 3 | ekibastuz
# Processing Record 40 of Set 3 | ostersund
# Processing Record 41 of Set 3 | lata
# Processing Record 42 of Set 3 | umm lajj
# Processing Record 43 of Set 3 | takab
# Processing Record 44 of Set 3 | poum
# Processing Record 45 of Set 3 | mahebourg
# Processing Record 46 of Set 3 | nikolskoye
# Processing Record 47 of Set 3 | kaitangata
# Processing Record 48 of Set 3 | meulaboh
# Processing Record 49 of Set 3 | dikson
# Processing Record 50 of Set 3 | port hardy
# Processing Record 1 of Set 4 | codrington
# Processing Record 2 of Set 4 | san cristobal
# Processing Record 3 of Set 4 | skara
# Processing Record 4 of Set 4 | quimper
# Processing Record 5 of Set 4 | jalalabad
# Processing Record 6 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 7 of Set 4 | chunhuhub
# Processing Record 8 of Set 4 | hornepayne
# Processing Record 9 of Set 4 | mandera
# Processing Record 10 of Set 4 | tutoia
# Processing Record 11 of Set 4 | qaqortoq
# Processing Record 12 of Set 4 | sur
# Processing Record 13 of Set 4 | faanui
# Processing Record 14 of Set 4 | vila franca do campo
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | tiksi
# Processing Record 17 of Set 4 | warsaw
# Processing Record 18 of Set 4 | vieques
# Processing Record 19 of Set 4 | walvis bay
# Processing Record 20 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 4 | verkhnevilyuysk
# Processing Record 22 of Set 4 | kirakira
# Processing Record 23 of Set 4 | upernavik
# Processing Record 24 of Set 4 | kavaratti
# Processing Record 25 of Set 4 | winslow
# Processing Record 26 of Set 4 | sisimiut
# Processing Record 27 of Set 4 | oyama
# Processing Record 28 of Set 4 | basoko
# Processing Record 29 of Set 4 | bull savanna
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | ushibuka
# Processing Record 32 of Set 4 | ust-maya
# Processing Record 33 of Set 4 | lavrentiya
# Processing Record 34 of Set 4 | arman
# Processing Record 35 of Set 4 | siuri
# Processing Record 36 of Set 4 | butembo
# Processing Record 37 of Set 4 | belaya gora
# Processing Record 38 of Set 4 | los llanos de aridane
# Processing Record 39 of Set 4 | oga
# Processing Record 40 of Set 4 | huanan
# Processing Record 41 of Set 4 | unai
# Processing Record 42 of Set 4 | kieta
# Processing Record 43 of Set 4 | lebu
# Processing Record 44 of Set 4 | outlook
# Processing Record 45 of Set 4 | bredasdorp
# Processing Record 46 of Set 4 | chamonix-mont-blanc
# Processing Record 47 of Set 4 | gbadolite
# Processing Record 48 of Set 4 | east london
# Processing Record 49 of Set 4 | cherskiy
# Processing Record 50 of Set 4 | tautira
# Processing Record 1 of Set 5 | georgetown
# Processing Record 2 of Set 5 | vadso
# Processing Record 3 of Set 5 | batticaloa
# Processing Record 4 of Set 5 | ijaki
# City not found. Skipping...
# Processing Record 5 of Set 5 | hami
# Processing Record 6 of Set 5 | carlsbad
# Processing Record 7 of Set 5 | loandjili
# Processing Record 8 of Set 5 | kavieng
# Processing Record 9 of Set 5 | mogok
# Processing Record 10 of Set 5 | gladstone
# Processing Record 11 of Set 5 | san quintin
# Processing Record 12 of Set 5 | gambela
# Processing Record 13 of Set 5 | antalaha
# Processing Record 14 of Set 5 | teplyk
# Processing Record 15 of Set 5 | manavalakurichi
# Processing Record 16 of Set 5 | fort pierce
# Processing Record 17 of Set 5 | shakiso
# Processing Record 18 of Set 5 | saint-pierre
# Processing Record 19 of Set 5 | kurchum
# Processing Record 20 of Set 5 | cidreira
# Processing Record 21 of Set 5 | carnduff
# Processing Record 22 of Set 5 | qingdao
# Processing Record 23 of Set 5 | miyako
# Processing Record 24 of Set 5 | port hedland
# Processing Record 25 of Set 5 | colares
# Processing Record 26 of Set 5 | severo-kurilsk
# Processing Record 27 of Set 5 | flinders
# Processing Record 28 of Set 5 | stornoway
# Processing Record 29 of Set 5 | mezen
# Processing Record 30 of Set 5 | buraydah
# Processing Record 31 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 32 of Set 5 | torbay
# Processing Record 33 of Set 5 | lorengau
# Processing Record 34 of Set 5 | geraldton
# Processing Record 35 of Set 5 | kodiak
# Processing Record 36 of Set 5 | port lincoln
# Processing Record 37 of Set 5 | batagay-alyta
# Processing Record 38 of Set 5 | burnie
# Processing Record 39 of Set 5 | dingle
# Processing Record 40 of Set 5 | emba
# Processing Record 41 of Set 5 | talcahuano
# Processing Record 42 of Set 5 | lagoa
# Processing Record 43 of Set 5 | leh
# Processing Record 44 of Set 5 | bitung
# Processing Record 45 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 46 of Set 5 | ko samui
# Processing Record 47 of Set 5 | santa maria
# Processing Record 48 of Set 5 | tebingtinggi
# Processing Record 49 of Set 5 | amahai
# Processing Record 50 of Set 5 | husavik
# Processing Record 1 of Set 6 | ponta do sol
# Processing Record 2 of Set 6 | dolinsk
# Processing Record 3 of Set 6 | barela
# Processing Record 4 of Set 6 | freeport
# Processing Record 5 of Set 6 | aklavik
# Processing Record 6 of Set 6 | salalah
# Processing Record 7 of Set 6 | arraial do cabo
# Processing Record 8 of Set 6 | ayan
# Processing Record 9 of Set 6 | vredendal
# Processing Record 10 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 6 | sibolga
# Processing Record 12 of Set 6 | leningradskiy
# Processing Record 13 of Set 6 | minab
# Processing Record 14 of Set 6 | asfi
# Processing Record 15 of Set 6 | ambodifototra
# City not found. Skipping...
# Processing Record 16 of Set 6 | alofi
# Processing Record 17 of Set 6 | aktau
# Processing Record 18 of Set 6 | samaro
# Processing Record 19 of Set 6 | beringovskiy
# Processing Record 20 of Set 6 | tuy hoa
# Processing Record 21 of Set 6 | clyde river
# Processing Record 22 of Set 6 | huarmey
# Processing Record 23 of Set 6 | mantua
# Processing Record 24 of Set 6 | campos belos
# Processing Record 25 of Set 6 | lufilufi
# Processing Record 26 of Set 6 | nuristan
# Processing Record 27 of Set 6 | hidalgo
# Processing Record 28 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 29 of Set 6 | bilma
# Processing Record 30 of Set 6 | vao
# Processing Record 31 of Set 6 | panguna
# Processing Record 32 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 6 | iguape
# Processing Record 34 of Set 6 | sinnamary
# Processing Record 35 of Set 6 | maneromango
# Processing Record 36 of Set 6 | tandil
# Processing Record 37 of Set 6 | bonfim
# Processing Record 38 of Set 6 | nome
# Processing Record 39 of Set 6 | kuhestan
# City not found. Skipping...
# Processing Record 40 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 6 | chorozinho
# Processing Record 42 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 43 of Set 6 | nurmijarvi
# Processing Record 44 of Set 6 | komsomolskiy
# Processing Record 45 of Set 6 | manokwari
# Processing Record 46 of Set 6 | te anau
# Processing Record 47 of Set 6 | ilulissat
# Processing Record 48 of Set 6 | aquiraz
# Processing Record 49 of Set 6 | kainantu
# Processing Record 50 of Set 6 | unguia
# Processing Record 1 of Set 7 | provideniya
# Processing Record 2 of Set 7 | kloulklubed
# Processing Record 3 of Set 7 | khani
# Processing Record 4 of Set 7 | chadiza
# Processing Record 5 of Set 7 | talnakh
# Processing Record 6 of Set 7 | shu
# Processing Record 7 of Set 7 | juneau
# Processing Record 8 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 9 of Set 7 | kahului
# Processing Record 10 of Set 7 | chaoyang
# Processing Record 11 of Set 7 | clarence town
# Processing Record 12 of Set 7 | bilibino
# Processing Record 13 of Set 7 | shubarshi
# Processing Record 14 of Set 7 | pisco
# Processing Record 15 of Set 7 | kamenka
# Processing Record 16 of Set 7 | veraval
# Processing Record 17 of Set 7 | baykit
# Processing Record 18 of Set 7 | kokopo
# Processing Record 19 of Set 7 | ginda
# Processing Record 20 of Set 7 | sistranda
# Processing Record 21 of Set 7 | athens
# Processing Record 22 of Set 7 | east wenatchee bench
# Processing Record 23 of Set 7 | sao joao da barra
# Processing Record 24 of Set 7 | owando
# Processing Record 25 of Set 7 | cuamba
# Processing Record 26 of Set 7 | belmonte
# Processing Record 27 of Set 7 | deputatskiy
# Processing Record 28 of Set 7 | abu samrah
# Processing Record 29 of Set 7 | dicamay
# Processing Record 30 of Set 7 | kinsale
# Processing Record 31 of Set 7 | mangrol
# Processing Record 32 of Set 7 | berlevag
# Processing Record 33 of Set 7 | brae
# Processing Record 34 of Set 7 | burriana
# Processing Record 35 of Set 7 | sorong
# Processing Record 36 of Set 7 | nanortalik
# Processing Record 37 of Set 7 | pasighat
# Processing Record 38 of Set 7 | ondjiva
# Processing Record 39 of Set 7 | khadyzhensk
# Processing Record 40 of Set 7 | gobabis
# Processing Record 41 of Set 7 | derzhavinsk
# Processing Record 42 of Set 7 | camacha
# Processing Record 43 of Set 7 | bundaberg
# Processing Record 44 of Set 7 | luang prabang
# Processing Record 45 of Set 7 | katsuura
# Processing Record 46 of Set 7 | bandipur
# Processing Record 47 of Set 7 | vuktyl
# Processing Record 48 of Set 7 | pozo de gamboa
# City not found. Skipping...
# Processing Record 49 of Set 7 | schortens
# Processing Record 50 of Set 7 | tateyama
# Processing Record 1 of Set 8 | kysyl-syr
# Processing Record 2 of Set 8 | tshikapa
# Processing Record 3 of Set 8 | dunda
# Processing Record 4 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 8 | porto nacional
# Processing Record 6 of Set 8 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 7 of Set 8 | bima
# Processing Record 8 of Set 8 | cabo san lucas
# Processing Record 9 of Set 8 | gizo
# Processing Record 10 of Set 8 | ancud
# Processing Record 11 of Set 8 | xai-xai
# Processing Record 12 of Set 8 | carballo
# Processing Record 13 of Set 8 | broome
# Processing Record 14 of Set 8 | nantucket
# Processing Record 15 of Set 8 | wagga wagga
# Processing Record 16 of Set 8 | sao felix do xingu
# Processing Record 17 of Set 8 | kyaikkami
# Processing Record 18 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 19 of Set 8 | chulym
# Processing Record 20 of Set 8 | bubaque
# Processing Record 21 of Set 8 | kindersley
# Processing Record 22 of Set 8 | tromso
# Processing Record 23 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 24 of Set 8 | guerrero negro
# Processing Record 25 of Set 8 | solnechnyy
# Processing Record 26 of Set 8 | laramie
# Processing Record 27 of Set 8 | biak
# Processing Record 28 of Set 8 | arroio grande
# Processing Record 29 of Set 8 | idenao
# Processing Record 30 of Set 8 | voi
# Processing Record 31 of Set 8 | inyonga
# Processing Record 32 of Set 8 | calama
# Processing Record 33 of Set 8 | bengkulu
# Processing Record 34 of Set 8 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 35 of Set 8 | soyo
# Processing Record 36 of Set 8 | kimbe
# Processing Record 37 of Set 8 | brookhaven
# Processing Record 38 of Set 8 | havre
# Processing Record 39 of Set 8 | cururupu
# Processing Record 40 of Set 8 | xining
# Processing Record 41 of Set 8 | irbil
# Processing Record 42 of Set 8 | talaya
# Processing Record 43 of Set 8 | ziarat
# Processing Record 44 of Set 8 | kosa
# Processing Record 45 of Set 8 | lompoc
# Processing Record 46 of Set 8 | megion
# Processing Record 47 of Set 8 | san jose
# Processing Record 48 of Set 8 | kyra
# Processing Record 49 of Set 8 | narok
# Processing Record 50 of Set 8 | el cope
# Processing Record 1 of Set 9 | cumaribo
# City not found. Skipping...
# Processing Record 2 of Set 9 | olafsvik
# Processing Record 3 of Set 9 | lavras
# Processing Record 4 of Set 9 | juxian
# City not found. Skipping...
# Processing Record 5 of Set 9 | pacific grove
# Processing Record 6 of Set 9 | letterkenny
# Processing Record 7 of Set 9 | coos bay
# Processing Record 8 of Set 9 | kagadi
# Processing Record 9 of Set 9 | razdolinsk
# Processing Record 10 of Set 9 | cedar rapids
# Processing Record 11 of Set 9 | fatehpur
# Processing Record 12 of Set 9 | lasa
# Processing Record 13 of Set 9 | axim
# Processing Record 14 of Set 9 | harper
# Processing Record 15 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 9 | gravdal
# Processing Record 17 of Set 9 | falmouth
# Processing Record 18 of Set 9 | alanya
# Processing Record 19 of Set 9 | jumla
# Processing Record 20 of Set 9 | tamiahua
# Processing Record 21 of Set 9 | arawa
# Processing Record 22 of Set 9 | eura
# Processing Record 23 of Set 9 | tabou
# Processing Record 24 of Set 9 | catania
# Processing Record 25 of Set 9 | illapel
# Processing Record 26 of Set 9 | mehamn
# Processing Record 27 of Set 9 | san lawrenz
# Processing Record 28 of Set 9 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 29 of Set 9 | grande prairie
# Processing Record 30 of Set 9 | northam
# Processing Record 31 of Set 9 | weinan
# Processing Record 32 of Set 9 | kudahuvadhoo
# Processing Record 33 of Set 9 | auki
# Processing Record 34 of Set 9 | shalakusha
# Processing Record 35 of Set 9 | yulara
# Processing Record 36 of Set 9 | staryy nadym
# Processing Record 37 of Set 9 | dombarovskiy
# Processing Record 38 of Set 9 | nhulunbuy
# Processing Record 39 of Set 9 | hofn
# Processing Record 40 of Set 9 | sandpoint
# Processing Record 41 of Set 9 | bambous virieux
# Processing Record 42 of Set 9 | shalinskoye
# Processing Record 43 of Set 9 | lethem
# Processing Record 44 of Set 9 | anito
# Processing Record 45 of Set 9 | haapu
# City not found. Skipping...
# Processing Record 46 of Set 9 | namibe
# Processing Record 47 of Set 9 | siyabuswa
# Processing Record 48 of Set 9 | toamasina
# Processing Record 49 of Set 9 | egtved
# Processing Record 50 of Set 9 | karpogory
# Processing Record 1 of Set 10 | la romana
# Processing Record 2 of Set 10 | manaure
# Processing Record 3 of Set 10 | saint-georges
# Processing Record 4 of Set 10 | bac lieu
# Processing Record 5 of Set 10 | hurghada
# Processing Record 6 of Set 10 | turukhansk
# Processing Record 7 of Set 10 | grindavik
# Processing Record 8 of Set 10 | delta del tigre
# Processing Record 9 of Set 10 | totness
# Processing Record 10 of Set 10 | palauig
# Processing Record 11 of Set 10 | cangzhou
# Processing Record 12 of Set 10 | posse
# Processing Record 13 of Set 10 | sinjah
# City not found. Skipping...
# Processing Record 14 of Set 10 | mosquera
# Processing Record 15 of Set 10 | mana
# Processing Record 16 of Set 10 | yazman
# Processing Record 17 of Set 10 | turbat
# Processing Record 18 of Set 10 | ribas do rio pardo
# Processing Record 19 of Set 10 | lins
# Processing Record 20 of Set 10 | angoram
# Processing Record 21 of Set 10 | camana
# Processing Record 22 of Set 10 | bud
# Processing Record 23 of Set 10 | opuwo
# Processing Record 24 of Set 10 | guiratinga
# Processing Record 25 of Set 10 | visby
# Processing Record 26 of Set 10 | changji
# Processing Record 27 of Set 10 | oranjestad
# Processing Record 28 of Set 10 | manakara
# Processing Record 29 of Set 10 | port blair
# Processing Record 30 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 10 | ordubad
# Processing Record 32 of Set 10 | hermon
# Processing Record 33 of Set 10 | nabire
# Processing Record 34 of Set 10 | pascagoula
# Processing Record 35 of Set 10 | young
# Processing Record 36 of Set 10 | sorland
# Processing Record 37 of Set 10 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 38 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 39 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 40 of Set 10 | vitimskiy
# City not found. Skipping...
# Processing Record 41 of Set 10 | ust-kulom
# Processing Record 42 of Set 10 | lamu
# Processing Record 43 of Set 10 | itarema
# Processing Record 44 of Set 10 | bryant
# Processing Record 45 of Set 10 | kirkwood
# Processing Record 46 of Set 10 | catuday
# Processing Record 47 of Set 10 | ranong
# Processing Record 48 of Set 10 | adeje
# Processing Record 49 of Set 10 | chirongui
# Processing Record 50 of Set 10 | cairns
# Processing Record 1 of Set 11 | le port
# Processing Record 2 of Set 11 | margate
# Processing Record 3 of Set 11 | abiy adi
# City not found. Skipping...
# Processing Record 4 of Set 11 | normandin
# Processing Record 5 of Set 11 | chapayevka
# Processing Record 6 of Set 11 | cottonwood
# Processing Record 7 of Set 11 | khonuu
# City not found. Skipping...
# Processing Record 8 of Set 11 | boende
# Processing Record 9 of Set 11 | pochutla
# Processing Record 10 of Set 11 | coquimbo
# Processing Record 11 of Set 11 | abha
# Processing Record 12 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 13 of Set 11 | shelburne
# Processing Record 14 of Set 11 | nizhniy kuranakh
# Processing Record 15 of Set 11 | yanji
# Processing Record 16 of Set 11 | manono
# Processing Record 17 of Set 11 | magole
# Processing Record 18 of Set 11 | sar-e pul
# Processing Record 19 of Set 11 | rutana
# Processing Record 20 of Set 11 | kiruna
# Processing Record 21 of Set 11 | wasilla
# Processing Record 22 of Set 11 | beira
# Processing Record 23 of Set 11 | himora
# City not found. Skipping...
# Processing Record 24 of Set 11 | shiyan
# Processing Record 25 of Set 11 | boyabat
# Processing Record 26 of Set 11 | alvaraes
# Processing Record 27 of Set 11 | barcelona
# Processing Record 28 of Set 11 | wucheng
# Processing Record 29 of Set 11 | aswan
# Processing Record 30 of Set 11 | englewood
# Processing Record 31 of Set 11 | lovozero
# Processing Record 32 of Set 11 | erzurum
# Processing Record 33 of Set 11 | saint-louis
# Processing Record 34 of Set 11 | lazaro cardenas
# Processing Record 35 of Set 11 | kinkala
# Processing Record 36 of Set 11 | vila velha
# Processing Record 37 of Set 11 | sao filipe
# Processing Record 38 of Set 11 | hay river
# Processing Record 39 of Set 11 | abu dhabi
# Processing Record 40 of Set 11 | nuevo laredo
# Processing Record 41 of Set 11 | haines junction
# Processing Record 42 of Set 11 | luhyny
# Processing Record 43 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 44 of Set 11 | thunder bay
# Processing Record 45 of Set 11 | sabha
# Processing Record 46 of Set 11 | palmer
# Processing Record 47 of Set 11 | bathsheba
# Processing Record 48 of Set 11 | yaounde
# Processing Record 49 of Set 11 | moss vale
# Processing Record 50 of Set 11 | guiberoua
# Processing Record 1 of Set 12 | port dickson
# Processing Record 2 of Set 12 | kama
# Processing Record 3 of Set 12 | thinadhoo
# Processing Record 4 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 5 of Set 12 | kununurra
# Processing Record 6 of Set 12 | isangel
# Processing Record 7 of Set 12 | wanning
# Processing Record 8 of Set 12 | aykhal
# Processing Record 9 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 10 of Set 12 | qui nhon
# Processing Record 11 of Set 12 | tomatlan
# Processing Record 12 of Set 12 | dolores
# Processing Record 13 of Set 12 | lebyazhye
# Processing Record 14 of Set 12 | aksha
# Processing Record 15 of Set 12 | dawei
# Processing Record 16 of Set 12 | nenjiang
# Processing Record 17 of Set 12 | linhares
# Processing Record 18 of Set 12 | kamaishi
# Processing Record 19 of Set 12 | heinola
# Processing Record 20 of Set 12 | lashio
# Processing Record 21 of Set 12 | venkatagiri
# Processing Record 22 of Set 12 | sembe
# Processing Record 23 of Set 12 | havoysund
# Processing Record 24 of Set 12 | nosy varika
# Processing Record 25 of Set 12 | jalu
# Processing Record 26 of Set 12 | svetlogorsk
# Processing Record 27 of Set 12 | yarkovo
# Processing Record 28 of Set 12 | padang
# Processing Record 29 of Set 12 | molina
# Processing Record 30 of Set 12 | nova olinda do norte
# Processing Record 31 of Set 12 | marabba
# Processing Record 32 of Set 12 | warrington
# Processing Record 33 of Set 12 | daru
# Processing Record 34 of Set 12 | maebaru
# Processing Record 35 of Set 12 | deder
# Processing Record 36 of Set 12 | gaoua
# Processing Record 37 of Set 12 | eureka
# Processing Record 38 of Set 12 | jinchang
# Processing Record 39 of Set 12 | hervey bay
# Processing Record 40 of Set 12 | chapleau
# Processing Record 41 of Set 12 | waddan
# Processing Record 42 of Set 12 | synya
# Processing Record 43 of Set 12 | budhlada
# Processing Record 44 of Set 12 | kupang
# Processing Record 45 of Set 12 | simcoe
# Processing Record 46 of Set 12 | boguchany
# Processing Record 47 of Set 12 | sylvan lake
# Processing Record 48 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 12 | zdvinsk
# Processing Record 50 of Set 12 | tommot
# Processing Record 1 of Set 13 | key west
# Processing Record 2 of Set 13 | olga
# Processing Record 3 of Set 13 | santa isabel do rio negro
# Processing Record 4 of Set 13 | pizhma
# Processing Record 5 of Set 13 | namatanai
# Processing Record 6 of Set 13 | necochea
# Processing Record 7 of Set 13 | caborca
# Processing Record 8 of Set 13 | mareeba
# Processing Record 9 of Set 13 | porto belo
# Processing Record 10 of Set 13 | konstantinovskoye
# Processing Record 11 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 12 of Set 13 | tigil
# Processing Record 13 of Set 13 | yelizovo
# Processing Record 14 of Set 13 | amot
# Processing Record 15 of Set 13 | comodoro rivadavia
# Processing Record 16 of Set 13 | hadejia
# Processing Record 17 of Set 13 | kuybyshevo
# Processing Record 18 of Set 13 | atar
# Processing Record 19 of Set 13 | eyl
# Processing Record 20 of Set 13 | mount gambier
# Processing Record 21 of Set 13 | kenai
# Processing Record 22 of Set 13 | presidencia roque saenz pena
# Processing Record 23 of Set 13 | khorixas
# Processing Record 24 of Set 13 | uznach
# Processing Record 25 of Set 13 | sabak
# Processing Record 26 of Set 13 | umm kaddadah
# Processing Record 27 of Set 13 | yakeshi
# Processing Record 28 of Set 13 | wad rawah
# Processing Record 29 of Set 13 | diffa
# Processing Record 30 of Set 13 | barreirinha
# Processing Record 31 of Set 13 | olinda
# Processing Record 32 of Set 13 | hanzhong
# Processing Record 33 of Set 13 | borama
# City not found. Skipping...
# Processing Record 34 of Set 13 | bafq
# Processing Record 35 of Set 13 | hirtshals
# Processing Record 36 of Set 13 | burica
# City not found. Skipping...
# Processing Record 37 of Set 13 | richards bay
# Processing Record 38 of Set 13 | santa marta
# Processing Record 39 of Set 13 | dongying
# Processing Record 40 of Set 13 | barlinek
# Processing Record 41 of Set 13 | yumen
# Processing Record 42 of Set 13 | solenzo
# Processing Record 43 of Set 13 | ahipara
# Processing Record 44 of Set 13 | la ronge
# Processing Record 45 of Set 13 | andradas
# Processing Record 46 of Set 13 | myrhorod
# Processing Record 47 of Set 13 | samarai
# Processing Record 48 of Set 13 | divnogorsk
# Processing Record 49 of Set 13 | mechetinskaya
# Processing Record 50 of Set 13 | dwarka
# Processing Record 1 of Set 14 | kinanah
# City not found. Skipping...
# Processing Record 2 of Set 14 | cukai
# Processing Record 3 of Set 14 | chinsali
# Processing Record 4 of Set 14 | omboue
# Processing Record 5 of Set 14 | mongo
# Processing Record 6 of Set 14 | mbaiki
# Processing Record 7 of Set 14 | puteyets
# Processing Record 8 of Set 14 | honningsvag
# Processing Record 9 of Set 14 | chunoyar
# Processing Record 10 of Set 14 | teya
# Processing Record 11 of Set 14 | salinopolis
# Processing Record 12 of Set 14 | xingcheng
# Processing Record 13 of Set 14 | ryotsu
# Processing Record 14 of Set 14 | ise
# Processing Record 15 of Set 14 | maningrida
# Processing Record 16 of Set 14 | kachug
# Processing Record 17 of Set 14 | buariki
# City not found. Skipping...
# Processing Record 18 of Set 14 | acatlan
# Processing Record 19 of Set 14 | korla
# Processing Record 20 of Set 14 | gorey
# Processing Record 21 of Set 14 | kutum
# Processing Record 22 of Set 14 | isoka
# Processing Record 23 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 24 of Set 14 | karratha
# Processing Record 25 of Set 14 | novikovo
# Processing Record 26 of Set 14 | matucana
# Processing Record 27 of Set 14 | clearwater
# Processing Record 28 of Set 14 | vanimo
# Processing Record 29 of Set 14 | saint-joseph
# Processing Record 30 of Set 14 | gamba
# Processing Record 31 of Set 14 | shahrud
# Processing Record 32 of Set 14 | kyshtovka
# Processing Record 33 of Set 14 | zhigansk
# Processing Record 34 of Set 14 | trapani
# Processing Record 35 of Set 14 | kytmanovo
# Processing Record 36 of Set 14 | klaksvik
# Processing Record 37 of Set 14 | north vanlaiphai
# Processing Record 38 of Set 14 | vidim
# Processing Record 39 of Set 14 | jutai
# Processing Record 40 of Set 14 | helong
# Processing Record 41 of Set 14 | mountain home
# Processing Record 42 of Set 14 | yarmouth
# Processing Record 43 of Set 14 | college
# Processing Record 44 of Set 14 | ciudad bolivar
# Processing Record 45 of Set 14 | windhoek
# Processing Record 46 of Set 14 | bouna
# Processing Record 47 of Set 14 | thaba-tseka
# Processing Record 48 of Set 14 | mapimi
# Processing Record 49 of Set 14 | banes
# Processing Record 50 of Set 14 | valparaiso
# Processing Record 1 of Set 15 | cayenne
# Processing Record 2 of Set 15 | kumylzhenskaya
# Processing Record 3 of Set 15 | whyalla
# Processing Record 4 of Set 15 | antsohihy
# Processing Record 5 of Set 15 | rawson
# Processing Record 6 of Set 15 | alugan
# Processing Record 7 of Set 15 | bauta
# Processing Record 8 of Set 15 | fare
# Processing Record 9 of Set 15 | sao gabriel da cachoeira
# Processing Record 10 of Set 15 | port shepstone
# Processing Record 11 of Set 15 | flin flon
# Processing Record 12 of Set 15 | pitimbu
# Processing Record 13 of Set 15 | pedasi
# Processing Record 14 of Set 15 | talara
# Processing Record 15 of Set 15 | sola
# Processing Record 16 of Set 15 | rio branco
# Processing Record 17 of Set 15 | pangkalanbuun
# Processing Record 18 of Set 15 | marsh harbour
# Processing Record 19 of Set 15 | yeppoon
# Processing Record 20 of Set 15 | at-bashi
# Processing Record 21 of Set 15 | tevaitoa
# Processing Record 22 of Set 15 | muros
# Processing Record 23 of Set 15 | de aar
# Processing Record 24 of Set 15 | hualmay
# Processing Record 25 of Set 15 | santarem
# Processing Record 26 of Set 15 | jind
# Processing Record 27 of Set 15 | coihaique
# Processing Record 28 of Set 15 | fianga
# City not found. Skipping...
# Processing Record 29 of Set 15 | villamontes
# Processing Record 30 of Set 15 | prince rupert
# Processing Record 31 of Set 15 | atbasar
# Processing Record 32 of Set 15 | kwinana
# Processing Record 33 of Set 15 | melilla
# Processing Record 34 of Set 15 | springdale
# Processing Record 35 of Set 15 | nadym
# Processing Record 36 of Set 15 | moindou
# Processing Record 37 of Set 15 | calabar
# Processing Record 38 of Set 15 | samana
# Processing Record 39 of Set 15 | putina
# Processing Record 40 of Set 15 | ewa beach
# Processing Record 41 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 15 | suntar
# Processing Record 43 of Set 15 | barra do corda
# Processing Record 44 of Set 15 | taltal
# Processing Record 45 of Set 15 | maku
# Processing Record 46 of Set 15 | sarkand
# Processing Record 47 of Set 15 | san andres
# Processing Record 48 of Set 15 | aborlan
# Processing Record 49 of Set 15 | camargo
# Processing Record 50 of Set 15 | sheridan
# Processing Record 1 of Set 16 | brindisi
# Processing Record 2 of Set 16 | bulungu
# Processing Record 3 of Set 16 | wuhan
# Processing Record 4 of Set 16 | artyk
# City not found. Skipping...
# Processing Record 5 of Set 16 | nicoya
# Processing Record 6 of Set 16 | ondorhaan
# City not found. Skipping...
# Processing Record 7 of Set 16 | bandarbeyla
# Processing Record 8 of Set 16 | narrabri
# Processing Record 9 of Set 16 | praia da vitoria
# Processing Record 10 of Set 16 | kanigiri
# Processing Record 11 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 16 | celestun
# Processing Record 13 of Set 16 | bage
# Processing Record 14 of Set 16 | marystown
# Processing Record 15 of Set 16 | alice springs
# Processing Record 16 of Set 16 | tete
# Processing Record 17 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 18 of Set 16 | centralia
# Processing Record 19 of Set 16 | bourail
# Processing Record 20 of Set 16 | maputo
# Processing Record 21 of Set 16 | caarapo
# Processing Record 22 of Set 16 | urusha
# Processing Record 23 of Set 16 | chilca
# Processing Record 24 of Set 16 | along
# Processing Record 25 of Set 16 | milos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_weather_df = pd.DataFrame(city_data)
city_weather_df.head()
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Baruun-Urt      MN  46.6806  113.2792     60.55        75
# 1             Bluff      NZ -46.6000  168.3333     49.80        89
# 2      Punta Arenas      CL -53.1500  -70.9167     37.51        87
# 3              Tura      IN  25.5198   90.2201     79.95        83
# 4  Fort Saint James      CA  54.4333 -124.2500     60.04        70
#
#    Cloudiness  Wind Speed Current Description
# 0         100       13.73     overcast clouds
# 1          97        4.85     overcast clouds
# 2           0       18.41           clear sky
# 3         100        5.48       moderate rain
# 4          67        2.15       broken clouds

# %%
city_weather_df.to_csv('WeatherPy_Database.csv')
